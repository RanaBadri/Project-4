# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("winequalityred.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.plot(x='quality', y='fixed acidity', kind="scatter", figsize = (12,10))
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
data.plot(x='quality', y='volatile acidity', kind="scatter", figsize = (12,10))
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
data.plot(x='quality', y='total sulfur dioxide', kind="scatter", figsize = (12,10))
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
data.plot(x='quality', y='free sulfur dioxide', kind="scatter", figsize = (12,10))
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
data.plot(x='quality', y='pH', kind="scatter", figsize = (12,10))
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>
